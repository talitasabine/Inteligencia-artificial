# %% [markdown]
# # **IIA007 2SEM2026 - Minimax**
# ## *Jogo de Palitos (Nim) - Atividade Prática de Programação*
#
# ### Disciplina: Inteligência Artificial e Aplicações - FATEC Ferraz de Vasconcelos
# ### Professora: Ana Rosa C. Tonão
# ### Data: 24/08/2026

# %%
import random

# %%
from agents import RandomAgent,AlphaBetaAgent
from game_engine import GameState, Referee

# %%
# Define the initial state of the game
initial_state = GameState(sticks=11) # 11 palitos

# %%
# The AlphaBetaAgent should always win if it goes first in 11-stick Nim
game = Referee(initial_state, AlphaBetaAgent(), RandomAgent())
game.play()
